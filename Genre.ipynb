# %%
# Import all the required libraries
import pandas as pd

# %%
# Load the Excel File
meta = pd.read_excel("metaClean43Brightspace.xlsx")

# %%
print(meta.columns)
# Out:
# Index(['url', 'title', 'studio', 'rating', 'runtime', 'cast', 'director',
#        'genre', 'summary', 'awards', 'metascore', 'userscore', 'RelDate'],
#       dtype='str')

# %%
# Remove unused columns
meta = meta.drop(columns=['url','studio','rating','runtime','cast','director','summary','awards','metascore','userscore','RelDate'])

# %%
meta.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11364 entries, 0 to 11363
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   11364 non-null  str
#  1   genre   11344 non-null  str
# dtypes: str(2)
# memory usage: 542.7 KB

# %%
meta.to_excel('genre.xlsx', index=False)
