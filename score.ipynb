# %%
import pandas as pd

# %%
movies = pd.read_csv("movie_lookup.csv")

score_data = movies[['movieid', 'userscore', 'metascore']].dropna().copy()

score_data['userscore'] = score_data['userscore'].astype(int)
score_data.to_csv("score.csv", index=False)
score_data.info()
# NEED TO CHANGE USERSCORE TO INT
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9259 entries, 0 to 11362
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   movieid    9259 non-null   int64
#  1   userscore  9259 non-null   int32
#  2   metascore  9259 non-null   int64
# dtypes: int32(1), int64(2)
# memory usage: 253.2 KB
