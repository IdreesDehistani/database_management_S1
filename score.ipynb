# %%
import pandas as pd

# %%
movies = pd.read_csv("movie_lookup.csv")

score_data = movies[['movieid', 'userscore', 'metascore']].dropna().copy()
print(score_data)
# Out:
#        movieid  userscore  metascore
# 0            1        7.2         59
# 1            2        8.1         72
# 2            3        7.9         61
# 3            4        6.3         41
# 4            5        5.8         19
# ...        ...        ...        ...
# 11358    11359        7.6         88
# 11359    11360        4.2         42
# 11360    11361        6.3         53
# 11361    11362        7.0         87
# 11362    11363        7.2         91
#
# [9259 rows x 3 columns]
